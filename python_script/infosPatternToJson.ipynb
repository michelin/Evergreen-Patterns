# %%
#Script who export Pattern Information to Json file in order to centralise information into a json file, for a better access to the mobile application

import os
path='../content'


for folder in os.listdir(path):
    print(folder)
    if folder == "patterns":
        print("patterns folder detected")
    elif folder == "anti-patterns":
        print("anti-patterns folder detected")


#Pattern
for categorie_mdfile in os.listdir(path_pattern):
    if os.path.isdir(path_pattern + "/" + categorie_mdfile):
        print("**CATEGORIE : " + categorie_mdfle + " **")
        for mdfile in os.listdir(path_pattern + "/" + categorie_mdfile):
            print(mdfile)
    else:
        print("mdfile detected : " + categorie_mdfile)
        
    print("\n")
# Out:
# anti-patterns
# anti-patterns folder detected
# categories
# patterns
# patterns folder detected
# **CATEGORIE : users.md **
# .ipynb_checkpoints
# integration-points.md
# rushing-to-solution.md
# sla-inversion.md
# unbalanced-capacities.md
# users.md
#
#
# **CATEGORIE : users.md **
# .ipynb_checkpoints
# architecting.md
# building.md
# releasing.md
# running.md
#
#
# **CATEGORIE : users.md **
# architecting
# building
# releasing
# running

# %%
import os
import re
import sys
import logging
import json
import pprint
#To add markdown,yaml parckage
#pip install --upgrade pip
#!{sys.executable} -m pip install markdown
#!{sys.executable} -m pip install pyyaml
#!{sys.executable} -m pip install python-frontmatter
import markdown
import yaml
import frontmatter

############################################################
#GET NUMBER OF MD FILE FOR EACH CATEGORIE
############################################################
dict_numbers_of_categories = {}

for subdir, dirs, files in os.walk(path):
    for file in files:
        if "categories" not in subdir:
            if re.findall(".md$", file):
                
                #print(os.path.join(subdir, file))
                md = frontmatter.load(os.path.join(subdir, file))
                
                if 'categories' not in md or md['categories'] == None or len(md['categories']) == 0:
                    if "NO CATEGORIES FOUND" not in dict_numbers_of_categories:
                        dict_numbers_of_categories['NO CATEGORIES FOUND'] = 1
                    else:
                        dict_numbers_of_categories['NO CATEGORIES FOUND'] = dict_numbers_of_categories['NO CATEGORIES FOUND'] + 1
                else:
                    for i in range(0, len(md['categories'])):
                        if md['categories'][i] not in dict_numbers_of_categories:
                            dict_numbers_of_categories[md['categories'][i]] = 1
                        else:
                            dict_numbers_of_categories[md['categories'][i]] = dict_numbers_of_categories[md['categories'][i]] + 1
                
print(dict_numbers_of_categories)





path='..\content'
logging.basicConfig(filename='myapp.log', level=logging.DEBUG, 
                    format='%(asctime)s %(levelname)s %(name)s %(message)s')
logger=logging.getLogger(__name__)
dict_tmp_categorie = {}
final_dict = {}
    
for subdir, dirs, files in os.walk(path):
    dict_temp = {}
    dict_categorie = {}
    for file in files:
        if "categories" not in subdir:
            if re.findall(".md$", file):
                
                #print(os.path.join(subdir, file))
                origin = subdir.split("\\")
                #print(origin[2])
                dict_data = {}
                
                try:
                    md = frontmatter.load(os.path.join(subdir, file))
                                            
                    #keep title from meta
                    if 'title' not in md or md['title'] == None or len(md['title']) == 0:
                        dict_data['title'] = "!!NO TITLE FOUND!!"
                    else:
                        #print(md['title'])
                        dict_data['title'] = md['title']
         
                    #keep description
                    if 'description' not in md or md['description'] == None or len(md['description']) == 0:
                        #print("!!NO DESCRIPTION FOUND!!")
                        dict_data['description'] = "!!NO DESCRIPTION FOUND!!"
                    else:
                        #print(md['description'])
                        dict_data['description'] = md['description']

                    #keep featured image
                    if 'featured_image' not in md or md['featured_image'] == None or len(md['featured_image']) == 0:
                        #print("!!NO FEATURED IMAGE FOUND!!")
                        dict_data['featured_image'] = "!!NO FEATURED IMAGE FOUND!!"
                    else:
                        #print(md['featured_image'])
                        dict_data['featured_image'] = md['featured_image']

                    #print(dict_data)  
                    #list_of_data.append(dict_data)
                    
                    #keep categorie
                    if 'categories' not in md or md['categories'] == None or len(md['categories']) == 0:
                        #print("!!NO CATEGORIES FOUND!!")
                        if "NO CATEGORIES FOUND" not in dict_tmp_categorie:
                            dict_tmp_categorie['NO CATEGORIES FOUND'] = 1
                            dict_categorie["NO CATEGORIES FOUND"] = "[" + str(dict_data)
                        else:
                            dict_tmp_categorie['NO CATEGORIES FOUND'] = dict_tmp_categorie['NO CATEGORIES FOUND'] + 1
                            if dict_tmp_categorie['NO CATEGORIES FOUND'] == dict_numbers_of_categories['NO CATEGORIES FOUND']:
                                dict_categorie["NO CATEGORIES FOUND"] += "," + str(dict_data) + "]"
                            else:
                                dict_categorie["NO CATEGORIES FOUND"] += "," + str(dict_data)
                    else:
                        for i in range(0, len(md['categories'])):
                            #print(md['categories'][i]) 
                            if md['categories'][i] not in dict_categorie:
                                dict_tmp_categorie[md['categories'][i]] = 1
                                dict_categorie[md['categories'][i]] = "[" + str(dict_data)
                            else:
                                dict_tmp_categorie[md['categories'][i]] = dict_tmp_categorie[md['categories'][i]] + 1
                                if dict_tmp_categorie[md['categories'][i]] == dict_numbers_of_categories[md['categories'][i]]:
                                    dict_categorie[md['categories'][i]] += "," + str(dict_data) + "]"
                                else:
                                    dict_categorie[md['categories'][i]] += "," + str(dict_data)
                    
                    
                    #print("dict_data => ")
                    #print(dict_data)
                    #pprint.pprint(dict_categorie)
                    #print(dict_categorie)
                    #print("\n")
                except Exception as e:
                    print(e)
                    logger.error(e)
                    print("\n")
       
    if len(dict_categorie) !=0:
        if  origin[2] not in final_dict:
            final_dict[origin[2]] = dict_categorie
        else:
            final_dict[origin[2]].update(dict_categorie)
            #final_dict[origin[2]] = [final_dict[origin[2]],dict_categorie]

pprint.pprint(final_dict)
with open("data.json", "w", encoding="utf8") as output_file:
    json.dump(final_dict, output_file)
# Out:
# {'NO CATEGORIES FOUND': 5, 'architecting': 6, 'building': 9, 'releasing': 4, 'running': 15}
# {'anti-patterns': {'NO CATEGORIES FOUND': "[{'title': 'Integration Points', "
#                                           "'description': 'My system isolate "
#                                           'functionalities to reduce the blast '
#                                           "radius when problems occur', "
#                                           "'featured_image': "
#                                           "'/images/icons/integration-points.png'},{'title': "
#                                           "'Rushing to Solution', "
#                                           "'description': 'Restoring a system "
#                                           'during an outage is the top '
#                                           'priority but not taking enough time '
#                                           "for collecting data or analyzing', "
#                                           "'featured_image': "
#                                           "'/images/icons/rushing-to-solution.png'},{'title': "
#                                           "'Sla Inversion', 'description': "
#                                           "'The availability of a system can "
#                                           'not exceed the availability of its '
#                                           "coupled dependencies', "
#                                           "'featured_image': "
#                                           "'/images/anti-patterns/sla-inversion.jpg'},{'title': "
#                                           "'Unbalanced Capacities', "
#                                           "'description': 'The resources "
#                                           'consumed by my system are '
#                                           'maladjusted to the tasks to be '
#                                           "performed', 'featured_image': "
#                                           "'/images/anti-patterns/unbalanced-capacities.jpg'},{'title': "
#                                           "'Users', 'description': 'You never "
#                                           "know how users will use a system', "
#                                           "'featured_image': "
#                                           "'/images/anti-patterns/users.jpg'}]"},
#  'patterns': {'architecting': "[{'title': 'Bulkhead', 'description': 'My "
#                               'system isolate functionalities to reduce the '
#                               "blast radius when problems occur', "
#                               "'featured_image': "
#                               "'/images/icons/bulkhead.png'},{'title': "
#                               "'Circuit Breaker', 'description': 'My systems "
#                               "are protected from third party failures', "
#                               "'featured_image': "
#                               "'/images/icons/circuit-breaker.png'},{'title': "
#                               "'Continuous Architecture', 'description': '!!NO "
#                               "DESCRIPTION FOUND!!', 'featured_image': "
#                               "'/images/icons/continuous_architecture.png'},{'title': "
#                               "'Defined Service Levels', 'description': '!!NO "
#                               "DESCRIPTION FOUND!!', 'featured_image': "
#                               "'/images/icons/define_service_levels.png'},{'title': "
#                               "'Reliable Data Exchanges', 'description': '!!NO "
#                               "DESCRIPTION FOUND!!', 'featured_image': "
#                               "'/images/icons/reliable_data_exchanges.png'},{'title': "
#                               "'Reliable Service Exposition', 'description': "
#                               "'!!NO DESCRIPTION FOUND!!', 'featured_image': "
#                               "'/images/icons/reliable_service_exposition.png'}]",
#               'building': "[{'title': 'Accounting for Internal Failures', "
#                           "'description': '!!NO DESCRIPTION FOUND!!', "
#                           "'featured_image': "
#                           "'/images/icons/accounting_for_internal_failures.png'},{'title': "
#                           "'Accounting for Third Party Failures', "
#                           "'description': '!!NO DESCRIPTION FOUND!!', "
#                           "'featured_image': "
#                           "'/images/icons/accounting_for_external_failures.png'},{'title': "
#                           "'Application Logging', 'description': '!!NO "
#                           "DESCRIPTION FOUND!!', 'featured_image': "
#                           "'/images/icons/application_logging.png'},{'title': "
#                           "'Chaos Engineering', 'description': '!!NO "
#                           "DESCRIPTION FOUND!!', 'featured_image': "
#                           "'/images/icons/Chaos_Monkey-31.png'},{'title': "
#                           "'Continuous Integration', 'description': '!!NO "
#                           "DESCRIPTION FOUND!!', 'featured_image': "
#                           "'/images/icons/continuous_integration.png'},{'title': "
#                           "'Error Categorization', 'description': '!!NO "
#                           "DESCRIPTION FOUND!!', 'featured_image': "
#                           "'/images/icons/error_integration.png'},{'title': "
#                           "'Production Aware Testing', 'description': '!!NO "
#                           "DESCRIPTION FOUND!!', 'featured_image': "
#                           "'/images/icons/production_aware_testing.png'},{'title': "
#                           "'Reporting System Health State', 'description': "
#                           "'!!NO DESCRIPTION FOUND!!', 'featured_image': "
#                           "'/images/icons/reporting_system_health_state.png'},{'title': "
#                           "'Traceability Of Data Flows', 'description': '!!NO "
#                           "DESCRIPTION FOUND!!', 'featured_image': "
#                           "'/images/icons/traceability_of_data_flows.png'}]",
#               'releasing': "[{'title': 'Continuous Deployment', 'description': "
#                            "'!!NO DESCRIPTION FOUND!!', 'featured_image': "
#                            "'/images/icons/continuous_deployment.png'},{'title': "
#                            "'Error Budget', 'description': '!!NO DESCRIPTION "
#                            "FOUND!!', 'featured_image': '!!NO FEATURED IMAGE "
#                            "FOUND!!'},{'title': 'Hypercare', 'description': "
#                            "'!!NO DESCRIPTION FOUND!!', 'featured_image': "
#                            "'!!NO FEATURED IMAGE FOUND!!'},{'title': "
#                            "'Progressive Roll Out', 'description': '!!NO "
#                            "DESCRIPTION FOUND!!', 'featured_image': "
#                            "'/images/icons/progressive-roll-out.png'}]",
#               'running': "[{'title': 'Andon', 'description': '!!NO DESCRIPTION "
#                          "FOUND!!', 'featured_image': "
#                          "'/images/icons/andon.png'},{'title': 'Capacity "
#                          "Planning', 'description': '!!NO DESCRIPTION "
#                          "FOUND!!', 'featured_image': "
#                          "'/images/icons/capacity_planning.png'},{'title': "
#                          "'Collecting Evidence', 'description': '!!NO "
#                          "DESCRIPTION FOUND!!', 'featured_image': "
#                          "'/images/icons/collecting-evidence.png'},{'title': "
#                          "'Continuous Knowledge', 'description': '!!NO "
#                          "DESCRIPTION FOUND!!', 'featured_image': "
#                          "'/images/icons/continuous_knowledge.png'},{'title': "
#                          "'Continuous Operability', 'description': '!!NO "
#                          "DESCRIPTION FOUND!!', 'featured_image': "
#                          "'/images/icons/continuous_operability.png'},{'title': "
#                          "'Embrace Failures', 'description': '!!NO DESCRIPTION "
#                          "FOUND!!', 'featured_image': "
#                          "'/images/icons/embrace_failures.png'},{'title': "
#                          "'Event Management', 'description': '!!NO DESCRIPTION "
#                          "FOUND!!', 'featured_image': "
#                          "'/images/icons/event_management.png'},{'title': "
#                          "'Immutability', 'description': '!!NO DESCRIPTION "
#                          "FOUND!!', 'featured_image': "
#                          "'/images/icons/immutabillity.png'},{'title': "
#                          "'Observability', 'description': '!!NO DESCRIPTION "
#                          "FOUND!!', 'featured_image': "
#                          "'/images/icons/observability.png'},{'title': 'Self "
#                          "Healing', 'description': '!!NO DESCRIPTION FOUND!!', "
#                          "'featured_image': "
#                          "'/images/icons/self_healing.png'},{'title': 'Smart "
#                          "Assistance', 'description': '!!NO DESCRIPTION "
#                          "FOUND!!', 'featured_image': "
#                          "'/images/icons/smart_assistance.png'},{'title': "
#                          "'Smoke Testing', 'description': '!!NO DESCRIPTION "
#                          "FOUND!!', 'featured_image': "
#                          "'/images/icons/smoke_testing.png'},{'title': 'Time "
#                          "Is Precious', 'description': '!!NO DESCRIPTION "
#                          "FOUND!!', 'featured_image': "
#                          "'/images/icons/time_is_precious.png'},{'title': "
#                          "'Traceability and Usage Monitoring', 'description': "
#                          "'!!NO DESCRIPTION FOUND!!', 'featured_image': "
#                          "'/images/icons/traceability_usage_monitoring.png'},{'title': "
#                          "'Up To Date Inventory', 'description': '!!NO "
#                          "DESCRIPTION FOUND!!', 'featured_image': "
#                          "'/images/icons/up_to_date_inventory.png'}]"}}

# %%
    {'pattern' : {
        'Architecting' : [
            {
                'title' : 'Circuite Breaker',
                'description' : '...',
                'featured_image' : '...'
            },
            {
                'title' : 'Circuite Breaker',
                'description' : '...',
                'featured_image' : '...'
            },
            {
                'title' : 'Circuite Breaker',
                'description' : '...',
                'featured_image' : '...'
            }
        ],
        'Running':[
            {
                'title' : 'Circuite Breaker',
                'description' : '...',
                'featured_image' : '...'
            }
        ]
        
    },
    'Anti-Pattern' : {
        'Building' : [
            {
                'title' : 'Circuite Breaker',
                'description' : '...',
                'featured_image' : '...'
            }
        ]
    }
    
}
# Out:
# {'pattern': {'Architecting': [{'title': 'Circuite Breaker',
#     'description': '...',
#     'featured_image': '...'},
#    {'title': 'Circuite Breaker',
#     'description': '...',
#     'featured_image': '...'},
#    {'title': 'Circuite Breaker',
#     'description': '...',
#     'featured_image': '...'}],
#   'Running': [{'title': 'Circuite Breaker',
#     'description': '...',
#     'featured_image': '...'}]},
#  'Anti-Pattern': {'Building': [{'title': 'Circuite Breaker',
#     'description': '...',
#     'featured_image': '...'}]}}

# %%
dict_numbers_of_categories = {}

for subdir, dirs, files in os.walk(path):
    for file in files:
        if "categories" not in subdir:
            if re.findall(".md$", file):
                
                #print(os.path.join(subdir, file))
                
                md = frontmatter.load(os.path.join(subdir, file))
                
                if 'categories' not in md or md['categories'] == None or len(md['categories']) == 0:
                    if "NO CATEGORIES FOUND" not in dict_numbers_of_categories:
                        dict_numbers_of_categories['NO CATEGORIES FOUND'] = 1
                    else:
                        dict_numbers_of_categories['NO CATEGORIES FOUND'] = dict_numbers_of_categories['NO CATEGORIES FOUND'] + 1
                else:
                    for i in range(0, len(md['categories'])):
                        if md['categories'][i] not in dict_numbers_of_categories:
                            dict_numbers_of_categories[md['categories'][i]] = 1
                        else:
                            dict_numbers_of_categories[md['categories'][i]] = dict_numbers_of_categories[md['categories'][i]] + 1

                
print(dict_numbers_of_categories)
# Out:
# {'NO CATEGORIES FOUND': 5, 'architecting': 6, 'building': 9, 'releasing': 4, 'running': 15}
